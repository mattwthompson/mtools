# %%
from mtools.post_process import calc_density
import mdtraj as md
import matplotlib.pyplot as plt
# Out:
# /Users/mwt/anaconda/envs/mosdef/lib/python3.5/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
traj = md.load('traj.xtc', top='confout.pdb')

# %%
rho = calc_density(traj, units='macro')

# %%
plt.figure()
plt.plot(traj.time, rho)
plt.show()
